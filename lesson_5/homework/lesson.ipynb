# %%
a=11
numbers=[1,2,3,4]
b=1 if a%2==0 else 2
print(b)
# Out:
# 2

# %%
numbers=[1,2,3,4]
a_even=['None' if not print(val) else 0 for val in numbers if val%2==0]
print(a_even)
# Out:
# 2
# 4
# ['None', 'None']

# %%
coordinates=[(x,y) for x in range(3) for y in range(3)]

# %%
matrix=[[1,2,3],[4,5,6]]
flattened=[val for row in matrix for val in row]

# %%
keys=['a','b','c']
values=[1,2,3]
d={key:value for (key, value) in zip(keys,values)}

# %%
matrix=[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
matrix_squares={pos:{num:num**2 for num in row} for pos, row in enumerate(matrix, start=1)}
print(matrix_squares)
# Out:
# {1: {1: 1, 2: 4, 3: 9}, 2: {4: 16, 5: 25, 6: 36}, 3: {7: 49, 8: 64, 9: 81}}

# %%
#set unique qiymat shunchun
cleaned=['a','as','asd','asd','asd','ss']
unique_words={word for word in cleaned if len(word)<3}
print(unique_words)
# Out:
# {'ss', 'a', 'as'}

# %%
#generator expression

#xotira doim saqlanib turmaydi

#faqat iteratsiya qilish mumkin

genaerator=(num for num in range(11))

print(next(a))

#
#o
#---
#1
#2
#3
